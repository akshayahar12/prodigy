# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_739890.csv')
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
country_population=df.groupby('Country Name')['1960'].sum().reset_index()
print(country_population)
# Out:
#                     Country Name          1960
# 0                    Afghanistan  8.622466e+06
# 1    Africa Eastern and Southern  1.306926e+08
# 2     Africa Western and Central  9.725629e+07
# 3                        Albania  1.608800e+06
# 4                        Algeria  1.139431e+07
# ..                           ...           ...
# 261           West Bank and Gaza  0.000000e+00
# 262                        World  3.031517e+09
# 263                  Yemen, Rep.  5.542459e+06
# 264                       Zambia  3.119430e+06
# 265                     Zimbabwe  3.806310e+06
#
# [266 rows x 2 columns]

# %%
country_population=country_population.sort_values('1960',ascending=False)
print(country_population)
# Out:
#                   Country Name          1960
# 262                      World  3.031517e+09
# 106           IDA & IBRD total  2.298248e+09
# 143        Low & middle income  2.115448e+09
# 162              Middle income  1.979685e+09
# 105                  IBRD only  1.904143e+09
# ..                         ...           ...
# 171                      Nauru  4.582000e+03
# 227   St. Martin (French part)  4.135000e+03
# 213  Sint Maarten (Dutch part)  2.646000e+03
# 261         West Bank and Gaza  0.000000e+00
# 183             Not classified  0.000000e+00
#
# [266 rows x 2 columns]

# %%
top_10_countries=country_population.head(10)
print(top_10_countries)
# Out:
#                    Country Name          1960
# 262                       World  3.031517e+09
# 106            IDA & IBRD total  2.298248e+09
# 143         Low & middle income  2.115448e+09
# 162               Middle income  1.979685e+09
# 105                   IBRD only  1.904143e+09
# 254         Upper middle income  1.150381e+09
# 131   Late-demographic dividend  1.095549e+09
# 63          East Asia & Pacific  1.043334e+09
# 62   Early-demographic dividend  9.794615e+08
# 101                 High income  9.079124e+08

# %%
plt.bar(top_10_countries['Country Name'],top_10_countries['1960'])
plt.xlabel('country')
plt.ylabel('population(thousands)')
plt.title('top 10 countries by population')
plt.show()
